# %%
from random import *
from math import *
import string
for i in xrange(20):
    n=int(floor(2+6*random()))
    #print n
    print "".join(sample(string.ascii_lowercase*n,n))
# Out:
# ew
# zqsx
# dlr
# uddty
# pmndb
# mns
# gvxe
# rbk
# yrts
# ehmyj
# ygu
# bl
# tjiwp
# ox
# dirrgjm
# mknofrm
# izkmvt
# din
# wcnij
# agcgv

# %%
from random import *
from math import *
from string import *
c1=1
c2=1
aList = []
tempList = []
#generate random array for the object
for i in xrange(10):
    aList.append([])
    n=int(floor(2+10*random()))
    aList[i].append("".join(sample(ascii_lowercase*n,n)))
#comparison algo
for l in xrange(10):
    i = int(floor(10*random()))
    j = int(floor(10*random()))
    l1 = len(aList[i])
    l2 = len(aList[j])
    match = False
    for c1 in xrange(l1):
        str1 = aList[i][c1]
        print str1
        for c2 in xrange(l2):
            if str1 == aList[j][c2]:
                match = True
                str2 = str1
            else:
                tempList.append(aList[j][c2])
        tempList.append(str1)
    if match == True:
         aList[i]=aList[j]=[str2]
    else:
        aList[i]=aList[j]=tempList
print aList
# Out:
# unvblkn
# afoqum
# adwttr
# qbdviyjdmq
# ugrzfj
# unvblkn
# afoqum
# neshf
# adwttr
# ugrzfj
# unvblkn
# afoqum
# neshf
# adwttr
# qbdviyjdmq
# anyqzn
# cnkmqksfw
# ugrzfj
# unvblkn
# afoqum
# neshf
# adwttr
# ugrzfj
# unvblkn
# afoqum
# neshf
# adwttr
# qbdviyjdmq
# unvblkn
# afoqum
# neshf
# adwttr
# unvblkn
# afoqum
# neshf
# adwttr
# qbdviyjdmq
# ugrzfj
# ugrzfj
# afoqum
# neshf
# adwttr
# ugrzfj
# afoqum
# neshf
# adwttr
# qbdviyjdmq
# unvblkn
# ugrzfj
# unvblkn
# neshf
# adwttr
# ugrzfj
# unvblkn
# neshf
# adwttr
# qbdviyjdmq
# afoqum
# ugrzfj
# unvblkn
# afoqum
# adwttr
# ugrzfj
# unvblkn
# afoqum
# adwttr
# qbdviyjdmq
# neshf
# ugrzfj
# unvblkn
# afoqum
# neshf
# ugrzfj
# unvblkn
# afoqum
# neshf
# qbdviyjdmq
# adwttr
# unvblkn
# afoqum
# neshf
# adwttr
# unvblkn
# afoqum
# neshf
# adwttr
# qbdviyjdmq
# ugrzfj
# ugrzfj
# afoqum
# neshf
# adwttr
# ugrzfj
# afoqum
# neshf
# adwttr
# qbdviyjdmq
# unvblkn
# ugrzfj
# unvblkn
# neshf
# adwttr
# ugrzfj
# unvblkn
# neshf
# adwttr
# ...
